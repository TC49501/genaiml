# %% [markdown]
# <a href="https://colab.research.google.com/github/TC49501/genaiml/blob/main/hf_summarizer_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 48.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 56.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 5.5 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline

# Load the summarizer pipeline with a pretrained model
summarizer = pipeline("summarization", model="google/pegasus-xsum")
# Out:
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# Some weights of PegasusForConditionalGeneration were not initialized from the model checkpoint at google/pegasus-xsum and are newly initialized: ['model.decoder.embed_positions.weight', 'model.encoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# generation_config.json:   0%|          | 0.00/259 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/87.0 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/1.91M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.52M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Device set to use cpu

# %%
def summarize_text(text):
    result = summarizer(text, max_length=130, min_length=30, do_sample=False)
    return result[0]['summary_text']

# %%
from IPython.display import display
import ipywidgets as widgets

text_area = widgets.Textarea(
    value='Paste a long text here...',
    placeholder='Enter text to summarize',
    description='Input:',
    layout=widgets.Layout(width='100%', height='200px')
)

button = widgets.Button(description="Summarize")
output = widgets.Output()

def on_button_click(b):
    with output:
        output.clear_output()
        summary = summarize_text(text_area.value)
        print("📝 Summary:\n", summary)

button.on_click(on_button_click)

display(text_area, button, output)
# Out:
# Textarea(value='Paste a long text here...', description='Input:', layout=Layout(height='200px', width='100%'),…
# Button(description='Summarize', style=ButtonStyle())
# Output()
